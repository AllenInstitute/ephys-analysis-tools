# %%
from jem_functions import generate_jem_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from jem_functions import generate_jem_df
#
# File c:\Users\svc_ivscc\Documents\GitHub\ephys-analysis-tools\src\run_scripts\functions\jem_functions.py:21
#      19 from datetime import datetime, date, timedelta
#      20 # File imports
# ---> 21 from functions.file_functions import get_jsons, load_data_variables
#      22 from functions.jem_data_set import JemDataSet
#      25 #-----Variables-----#
#      26 # Load json file
#
# ModuleNotFoundError: No module named 'functions'
